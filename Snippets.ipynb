# %%
people = {
    "first": ["Mansi", "Manan", "Komal", "Sujal"],
    "last": ["Kothari", "Jain", "Kothari", "Jain"],
    "email": ["mansikothari46@gmail.com", "kotharimanan46@gmail.com", "komalexample@gmail.com", "sujalexample@gmail.com"]
}

# %%
people['email']
# Out:
# ['mansikothari46@gmail.com',
#  'kotharimanan46@gmail.com',
#  'komalexample@gmail.com',
#  'sujalexample@gmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                     email
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 1  Manan     Jain  kotharimanan46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com
# 3  Sujal     Jain    sujalexample@gmail.com

# %%
df.sort_values(by='first', ascending=False)
# Out:
#    first     last                     email
# 3  Sujal     Jain    sujalexample@gmail.com
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 1  Manan     Jain  kotharimanan46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com

# %%
df.loc[4] = ['Sujal', 'Malhotra', 'suajlmalhotra@gmail.com']

# %%
df
# Out:
#    first      last                     email
# 0  Mansi   Kothari  mansikothari46@gmail.com
# 1  Manan      Jain  kotharimanan46@gmail.com
# 2  Komal   Kothari    komalexample@gmail.com
# 3  Sujal      Jain    sujalexample@gmail.com
# 4  Sujal  Malhotra   suajlmalhotra@gmail.com

# %%
df.sort_values(by=['first', 'last'], ascending=False)
# Out:
#    first      last                     email
# 4  Sujal  Malhotra   suajlmalhotra@gmail.com
# 3  Sujal      Jain    sujalexample@gmail.com
# 0  Mansi   Kothari  mansikothari46@gmail.com
# 1  Manan      Jain  kotharimanan46@gmail.com
# 2  Komal   Kothari    komalexample@gmail.com

# %%
df.loc[5] = ['Sujal', 'Kothari', 'suajlkothari@gmail.com']

# %%
df.sort_values(by=['first', 'last'], ascending=[False, True], inplace = True)

# %%
df
# Out:
#    first      last                     email
# 3  Sujal      Jain    sujalexample@gmail.com
# 5  Sujal   Kothari    suajlkothari@gmail.com
# 4  Sujal  Malhotra   suajlmalhotra@gmail.com
# 0  Mansi   Kothari  mansikothari46@gmail.com
# 1  Manan      Jain  kotharimanan46@gmail.com
# 2  Komal   Kothari    komalexample@gmail.com

# %%
df.sort_index()
# Out:
#    first      last                     email
# 0  Mansi   Kothari  mansikothari46@gmail.com
# 1  Manan      Jain  kotharimanan46@gmail.com
# 2  Komal   Kothari    komalexample@gmail.com
# 3  Sujal      Jain    sujalexample@gmail.com
# 4  Sujal  Malhotra   suajlmalhotra@gmail.com
# 5  Sujal   Kothari    suajlkothari@gmail.com

# %%
df['last'].sort_values()
# Out:
# 3        Jain
# 1        Jain
# 5     Kothari
# 0     Kothari
# 2     Kothari
# 4    Malhotra
# Name: last, dtype: str
