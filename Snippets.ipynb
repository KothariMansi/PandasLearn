# %%
person = {
    "first": "Mansi",
    "last": "Kothari",
    "email": "mansikothari46@gmail.com"
}

# %%
people = {
    "first": ["Mansi"],
    "last": ["Kothari"],
    "email": ["mansikothari46@gmail.com"]
}

# %%
people = {
    "first": ["Mansi", "Manan", "Komal", "Sujal"],
    "last": ["Kothari", "Jain", "Kothari", "Jain"],
    "email": ["mansikothari46@gmail.com", "kotharimanan46@gmail.com", "komalexample@gmail.com", "sujalexample@gmail.com"]
}

# %%
people['email']
# Out:
# ['mansikothari46@gmail.com',
#  'kotharimanan46@gmail.com',
#  'komalexample@gmail.com',
#  'sujalexample@gmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                     email
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 1  Manan     Jain  kotharimanan46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com
# 3  Sujal     Jain    sujalexample@gmail.com

# %%
df['email']
# Out:
# 0    mansikothari46@gmail.com
# 1    kotharimanan46@gmail.com
# 2      komalexample@gmail.com
# 3      sujalexample@gmail.com
# Name: email, dtype: str

# %%
type(df['email'])
# Out:
# pandas.Series

# %%
df.email
# Out:
# 0    mansikothari46@gmail.com
# 1    kotharimanan46@gmail.com
# 2      komalexample@gmail.com
# 3      sujalexample@gmail.com
# Name: email, dtype: str

# %%
df[["last","email"]]
# Out:
#       last                     email
# 0  Kothari  mansikothari46@gmail.com
# 1     Jain  kotharimanan46@gmail.com
# 2  Kothari    komalexample@gmail.com
# 3     Jain    sujalexample@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[0]
# Out:
# first                       Mansi
# last                      Kothari
# email    mansikothari46@gmail.com
# Name: 0, dtype: str

# %%
df.iloc[[0, 2]]
# Out:
#    first     last                     email
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com

# %%
df.iloc[[0, 1], [1, 2]]
# Out:
#       last                     email
# 0  Kothari  mansikothari46@gmail.com
# 1     Jain  kotharimanan46@gmail.com

# %%
df
# Out:
#    first     last                     email
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 1  Manan     Jain  kotharimanan46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com
# 3  Sujal     Jain    sujalexample@gmail.com

# %%
df.loc[0]
# Out:
# first                       Mansi
# last                      Kothari
# email    mansikothari46@gmail.com
# Name: 0, dtype: str

# %%
df.loc[[2, 3]]
# Out:
#    first     last                   email
# 2  Komal  Kothari  komalexample@gmail.com
# 3  Sujal     Jain  sujalexample@gmail.com

# %%
df.loc[[2, 3], 'email']
# Out:
# 2    komalexample@gmail.com
# 3    sujalexample@gmail.com
# Name: email, dtype: str

# %%
df.loc[[2, 3], ['first','last']]
# Out:
#    first     last
# 2  Komal  Kothari
# 3  Sujal     Jain

# %%
df
# Out:
#    first     last                     email
# 0  Mansi  Kothari  mansikothari46@gmail.com
# 1  Manan     Jain  kotharimanan46@gmail.com
# 2  Komal  Kothari    komalexample@gmail.com
# 3  Sujal     Jain    sujalexample@gmail.com

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                           first     last
# email
# mansikothari46@gmail.com  Mansi  Kothari
# kotharimanan46@gmail.com  Manan     Jain
# komalexample@gmail.com    Komal  Kothari
# sujalexample@gmail.com    Sujal     Jain

# %%
df.index
# Out:
# Index(['mansikothari46@gmail.com', 'kotharimanan46@gmail.com',
#        'komalexample@gmail.com', 'sujalexample@gmail.com'],
#       dtype='str', name='email')

# %%
df.loc['komalexample@gmail.com']
# Out:
# first      Komal
# last     Kothari
# Name: komalexample@gmail.com, dtype: str

# %%
df.iloc[2]
# Out:
# first      Komal
# last     Kothari
# Name: komalexample@gmail.com, dtype: str

# %%
df.reset_index(inplace=True)
df
# Out:
#                       email  first     last
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3    sujalexample@gmail.com  Sujal     Jain

# %%
df
# Out:
#                       email  first     last
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3    sujalexample@gmail.com  Sujal     Jain

# %%
df.columns
# Out:
# Index(['email', 'first', 'last'], dtype='str')

# %%
df.columns = ['first_name', 'last_name', 'email_address']

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email_address'], dtype='str')

# %%
df
# Out:
#                  first_name last_name email_address
# 0  mansikothari46@gmail.com     Mansi       Kothari
# 1  kotharimanan46@gmail.com     Manan          Jain
# 2    komalexample@gmail.com     Komal       Kothari
# 3    sujalexample@gmail.com     Sujal          Jain

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#                  FIRST_NAME LAST_NAME EMAIL_ADDRESS
# 0  mansikothari46@gmail.com     Mansi       Kothari
# 1  kotharimanan46@gmail.com     Manan          Jain
# 2    komalexample@gmail.com     Komal       Kothari
# 3    sujalexample@gmail.com     Sujal          Jain

# %%
df.columns = df.columns.str.replace('_', ' ')
df
# Out:
#                  FIRST NAME LAST NAME EMAIL ADDRESS
# 0  mansikothari46@gmail.com     Mansi       Kothari
# 1  kotharimanan46@gmail.com     Manan          Jain
# 2    komalexample@gmail.com     Komal       Kothari
# 3    sujalexample@gmail.com     Sujal          Jain

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#                  FIRST_NAME LAST_NAME EMAIL_ADDRESS
# 0  mansikothari46@gmail.com     Mansi       Kothari
# 1  kotharimanan46@gmail.com     Manan          Jain
# 2    komalexample@gmail.com     Komal       Kothari
# 3    sujalexample@gmail.com     Sujal          Jain

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                  first_name last_name email_address
# 0  mansikothari46@gmail.com     Mansi       Kothari
# 1  kotharimanan46@gmail.com     Manan          Jain
# 2    komalexample@gmail.com     Komal       Kothari
# 3    sujalexample@gmail.com     Sujal          Jain

# %%
df.rename(columns={'first_name':'first', 'last_name': 'last', 'email_address':'email'}, inplace=True)

# %%
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3       johnsmith@gmail.com  Smith     John

# %%
df.loc[3] = ['johnsmith@gmail.com', 'Smith', 'John']

# %%
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3       johnsmith@gmail.com  Smith     John

# %%
df.rename(columns={'first':'email', 'email':'first'}, inplace=True)

# %%
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3       johnsmith@gmail.com  Smith     John

# %%
df.columns
# Out:
# Index(['email', 'last', 'first'], dtype='str')

# %%
df.at[3, 'email'] = 'john@example.com'
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3          john@example.com   jain    sujal

# %%
filt = (df['email'] == 'john@example.com')
df[filt]['last'] = 'smith'
# Out:
# C:\Users\SHREE\AppData\Local\Temp\ipykernel_3872\238287783.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   df[filt]['last'] = 'smith'

# %%
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3          john@example.com   jain    sujal

# %%
filt = (df['email'] == 'john@example.com')
df.loc[filt, 'last'] = 'smith'
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3          john@example.com  smith    sujal

# %%
df['email'] = df['email'].str.upper()
df
# Out:
#                       email   last    first
# 0  MANSIKOTHARI46@GMAIL.COM  Mansi  Kothari
# 1  KOTHARIMANAN46@GMAIL.COM  Manan     Jain
# 2    KOMALEXAMPLE@GMAIL.COM  Komal  Kothari
# 3          JOHN@EXAMPLE.COM  smith    sujal

# %%
df['email'] = df['email'].str.lower()
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3          john@example.com  smith    sujal

# %%
df['email'].apply(len)
# Out:
# 0    24
# 1    24
# 2    22
# 3    16
# Name: email, dtype: int64

# %%
df['last'].apply(len)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# Name: last, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    MANSIKOTHARI46@GMAIL.COM
# 1    KOTHARIMANAN46@GMAIL.COM
# 2      KOMALEXAMPLE@GMAIL.COM
# 3            JOHN@EXAMPLE.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].apply(update_email)
df
# Out:
#                       email   last    first
# 0  MANSIKOTHARI46@GMAIL.COM  Mansi  Kothari
# 1  KOTHARIMANAN46@GMAIL.COM  Manan     Jain
# 2    KOMALEXAMPLE@GMAIL.COM  Komal  Kothari
# 3          JOHN@EXAMPLE.COM  smith    sujal

# %%
df['email'] = df['email'].apply(lambda x: x.lower())
df
# Out:
#                       email   last    first
# 0  mansikothari46@gmail.com  Mansi  Kothari
# 1  kotharimanan46@gmail.com  Manan     Jain
# 2    komalexample@gmail.com  Komal  Kothari
# 3          john@example.com  smith    sujal

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# email    john@example.com
# last                Komal
# first                Jain
# dtype: str

# %%
df.apply(lambda x: x.min())
# Out:
# email    john@example.com
# last                Komal
# first                Jain
# dtype: str

# %%
df.map(len)
# Out:
#    email  last  first
# 0     24     5      7
# 1     24     5      4
# 2     22     5      7
# 3     16     5      5

# %%
df.map(str.upper)
# Out:
#                       email   last    first
# 0  MANSIKOTHARI46@GMAIL.COM  MANSI  KOTHARI
# 1  KOTHARIMANAN46@GMAIL.COM  MANAN     JAIN
# 2    KOMALEXAMPLE@GMAIL.COM  KOMAL  KOTHARI
# 3          JOHN@EXAMPLE.COM  SMITH    SUJAL

# %%
df['first'] = ['Mansi', 'Manan', 'Komal', 'smith']
df['last'] = ['Kothari', 'Jain', 'Jain', 'Kothari']
df
# Out:
#                       email     last  first
# 0  mansikothari46@gmail.com  Kothari  Mansi
# 1  kotharimanan46@gmail.com     Jain  Manan
# 2    komalexample@gmail.com     Jain  Komal
# 3          john@example.com  Kothari  smith

# %%
df['first'] = df['first'].map({'Mansi':'dolly', 'Manan':'ramu', 'smith':'sujal', 'Komal': 'kamli'})
df
# Out:
#                       email     last  first
# 0  mansikothari46@gmail.com  Kothari  dolly
# 1  kotharimanan46@gmail.com     Jain   ramu
# 2    komalexample@gmail.com     Jain  kamli
# 3          john@example.com  Kothari  sujal

# %%
df['first'] = df['first'].replace({'sujal':'shamu'})
df
# Out:
#                       email     last  first
# 0  mansikothari46@gmail.com  Kothari  dolly
# 1  kotharimanan46@gmail.com     Jain   ramu
# 2    komalexample@gmail.com     Jain  kamli
# 3          john@example.com  Kothari  shamu
