# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', low_memory=False, index_col='ResponseId', na_values = 'na_vals')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 172)
pd.set_option('display.max_rows', 139)

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df['YearsCode'].tail(10)
# Out:
# ResponseId
# 49182     NaN
# 49183     NaN
# 49184     2.0
# 49185     NaN
# 49186     NaN
# 49187     NaN
# 49188     NaN
# 49189    31.0
# 49190     NaN
# 49191     6.0
# Name: YearsCode, dtype: float64

# %%
df['YearsCode'].mean()
# Out:
# np.float64(16.570861019469355)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# np.float64(16.570861019469355)

# %%
df['WorkExp'].apply(lambda x: x > 5).value_counts()
# Out:
# WorkExp
# True     30690
# False    18501
# Name: count, dtype: int64

# %%
df['YearsCode'].unique()
# Out:
# array([ 14.,  10.,  12.,   5.,  22.,  20.,  13.,  30.,  15.,   9.,   6.,
#         nan,   3.,  40.,   8.,  45.,  35.,  11.,   7.,  47.,  41.,  36.,
#         23.,  29.,  26.,  25.,  38.,  21.,  19.,  18.,  16.,   4.,  17.,
#         42.,  27.,  24.,   2.,  28.,  37.,  32.,   1.,  39.,  53.,  33.,
#         50.,  48.,  44.,  31.,  46.,  43.,  49.,  52.,  34.,  51.,  58.,
#         57.,  54.,  63.,  60.,  55.,  65., 100.,  99.,  56.,  69.,  90.,
#         61.,  67.,  75.,  64.,  98.,  68.,  89.,  62.,  78.,  70.,  76.,
#         82.,  59.])

# %%
df['YearsCode'].median()
# Out:
# np.float64(14.0)

# %%
filt = df['Country'] == 'India'
india_df = df[filt]
india_df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='ResponseId')

# %%
test.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
india_df.to_json('data/modifier.json')

# %%
india_df.to_json('data/modified.json', orient='records', lines=True)

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                        MainBranch              Age  \
# 0  I am a developer by profession  25-34 years old
# 1  I am a developer by profession  18-24 years old
# 2  I am a developer by profession  35-44 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
#
#                                         EdLevel Employment  \
# 0  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 3  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 4  Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                       EmploymentAddl  WorkExp  \
# 0    Caring for dependents (children, elderly, etc.)      6.0
# 1  Engaged in paid work (20-29 hours per week);En...      5.0
# 2                           Volunteering (regularly)      NaN
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://test_user:test_pass@localhost:5432/test_db')

# %%
india_df.to_sql('sample_table', engine)
# Out:
# 77

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='ResponseId')

# %%
sql_df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
#
#                                                EmploymentAddl  WorkExp  \
# ResponseId
# 14            Caring for dependents (children, elderly, etc.)      6.0
# ...

# %%
sql_df = pd.read_sql_query('''SELECT "ResponseId", "MainBranch", "Age", "EdLevel", "Employment" FROM sample_table''', engine, index_col='ResponseId')

# %%
sql_df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 14          I am a developer by profession  25-34 years old
# 16          I am a developer by profession  18-24 years old
# 47          I am a developer by profession  35-44 years old
# 91          I am a developer by profession  25-34 years old
# 134         I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment
# ResponseId
# 14          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 16          Bachelor’s degree (B.A., B.S., B.Eng., etc.)    Student
# 47          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 91          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# 134         Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/refs/heads/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
