# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', low_memory=False, index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns', 172)
pd.set_option('display.max_rows', 139)

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
df.sort_values(by=['Country', 'CompTotal'],ascending=[True, False], inplace=True)

# %%
df[['Country', 'CompTotal']].head(50)
# Out:
#                 Country   CompTotal
# ResponseId
# 40307       Afghanistan    700000.0
# 7077        Afghanistan    600000.0
# 45925       Afghanistan    500000.0
# 6010        Afghanistan     70000.0
# 40967       Afghanistan     65000.0
# 7925        Afghanistan     20000.0
# 7167        Afghanistan      5200.0
# 38609       Afghanistan      1000.0
# 6836        Afghanistan         NaN
# 15708       Afghanistan         NaN
# 19816       Afghanistan         NaN
# 44797       Afghanistan         NaN
# 27099       Afghanistan         NaN
# 28588           Albania  10004806.0
# 37731           Albania   5732910.0
# 33940           Albania   1500000.0
# 3888            Albania   1200000.0
# 2023            Albania    120000.0
# 3185            Albania     99999.0
# 35934           Albania     50000.0
# 14758           Albania     30000.0
# 16850           Albania     20000.0
# 48950           Albania     15000.0
# 22400           Albania        56.0
# ...

# %%
schema_df.loc['CompTotal']['question']
# Out:
# 'What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions) in terms of your day-to-day currency?  Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty. '

# %%
df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 4934     5.555556e+74
# 44527    8.000000e+23
# 35765    1.000000e+23
# 28546    9.223372e+18
# 22733    1.000000e+17
# 484      1.000000e+16
# 18755    1.000000e+15
# 39338    9.596957e+11
# 35354    6.500000e+11
# 39350    1.000000e+11
# Name: CompTotal, dtype: float64

# %%
df.nlargest(5, 'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 4934                           I am a developer by profession
# 44527                          I am a developer by profession
# 35765                          I am a developer by profession
# 28546                                   I am learning to code
# 22733       I work with developers or my work supports dev...
#
#                           Age  \
# ResponseId
# 4934          45-54 years old
# 44527         18-24 years old
# 35765         55-64 years old
# 28546       Prefer not to say
# 22733       65 years or older
#
#                                                       EdLevel  \
# ResponseId
# 4934                                  Other (please specify):
# 44527                                 Other (please specify):
# 35765         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 28546       Secondary school (e.g. American high school, G...
# ...

# %%
df.nsmallest(5, 'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 7106        I am not primarily a developer, but I write co...
# 28573                             I code primarily as a hobby
# 27412                          I am a developer by profession
# 49028                                   I am learning to code
# 35174                                   I am learning to code
#
#                         Age  \
# ResponseId
# 7106        18-24 years old
# 28573       25-34 years old
# 27412       18-24 years old
# 49028       25-34 years old
# 35174       18-24 years old
#
#                                                       EdLevel  \
# ResponseId
# 7106             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28573         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 27412       Secondary school (e.g. American high school, G...
# 49028       Some college/university study without earning ...
# 35174            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...
